# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
sns.set_palette('Set3')

import missingno as msno
import warnings
warnings.filterwarnings('ignore')

import scipy.stats

plt.rcParams["font.family"] = "NanumBarunGothic"

from category_encoders.target_encoder import TargetEncoder

# %% [markdown]
# #### 1. 충청남도 천안시 카페 가맹점 데이터 분석

# %%
path = "C:/Cafe_Test"

# 데이터 URL : https://www.data.go.kr/data/15083033/fileData.do
Top_Lib = pd.read_csv(path + '/Chungnam_Market_2312.csv', encoding='CP949')

num_rows, num_columns = Top_Lib.shape

# 결과 출력
print(f"데이터 수: {num_rows}")

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
# Out:
# 데이터 수: 111528

# %%
# information
Top_Lib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111528 entries, 0 to 111527
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     111528 non-null  object
#  1   상호명        111528 non-null  object
#  2   지점명        1679 non-null    object
#  3   상권업종대분류코드  111528 non-null  object
#  4   상권업종대분류명   111528 non-null  object
#  5   상권업종중분류코드  111528 non-null  object
#  6   상권업종중분류명   111528 non-null  object
#  7   상권업종소분류코드  111528 non-null  object
#  8   상권업종소분류명   111528 non-null  object
#  9   표준산업분류코드   111490 non-null  object
#  10  표준산업분류명    111490 non-null  object
#  11  시도코드       111528 non-null  int64
#  12  시도명        111528 non-null  object
#  13  시군구코드      111528 non-null  int64
#  14  시군구명       111528 non-null  object
#  15  행정동코드      111528 non-null  int64
#  16  행정동명       111528 non-null  object
#  17  법정동코드      111528 non-null  int64
#  18  법정동명       111528 non-null  object
#  19  지번코드       111528 non-null  int64
#  20  대지구분코드     111528 non-null  int64
#  21  대지구분명      111528 non-null  object
#  22  지번본번지      111519 non-null  float64
#  23  지번부번지      74734 non-null   float64
#  24  지번주소       111528 non-null  object
#  25  도로명코드      111528 non-null  int64
#  26  도로명        111528 non-null  object
#  27  건물본번지      111528 non-null  int64
#  28  건물부번지      29646 non-null   float64
#  29  건물관리번호     111526 non-null  object
#  30  건물명        34351 non-null   object
#  31  도로명주소      111528 non-null  object
#  32  구우편번호      111528 non-null  int64
#  33  신우편번호      111528 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        39177 non-null   object
#  36  호정보        0 non-null       float64
#  37  경도         111528 non-null  float64
#  38  위도         111528 non-null  float64
# dtypes: float64(7), int64(10), object(22)
# memory usage: 33.2+ MB

# %%
# 결측치 확인
msno.matrix(Top_Lib)
# Out:
# <Axes: >

# %%
# 결측값 퍼센트 확인
cols = ['시도코드','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','구우편번호','신우편번호','동정보','호정보','경도','위도']

print("----------------------충청남도 소상공 데이터 결측치 확인----------------------")
for col in cols:  
    print(f"column : {col} Nan value percentage : {round(Top_Lib[col].isna().sum() / len(Top_Lib) * 100 , 2)}%")



print("")
# Out:
# ----------------------충청남도 소상공 데이터 결측치 확인----------------------
# column : 시도코드 Nan value percentage : 0.0%
# column : 시군구코드 Nan value percentage : 0.0%
# column : 행정동코드 Nan value percentage : 0.0%
# column : 법정동코드 Nan value percentage : 0.0%
# column : 지번코드 Nan value percentage : 0.0%
# column : 대지구분코드 Nan value percentage : 0.0%
# column : 지번본번지 Nan value percentage : 0.01%
# column : 지번부번지 Nan value percentage : 32.99%
# column : 도로명코드 Nan value percentage : 0.0%
# column : 건물본번지 Nan value percentage : 0.0%
# column : 건물부번지 Nan value percentage : 73.42%
# column : 구우편번호 Nan value percentage : 0.0%
# column : 신우편번호 Nan value percentage : 0.0%
# column : 동정보 Nan value percentage : 100.0%
# column : 호정보 Nan value percentage : 100.0%
# column : 경도 Nan value percentage : 0.0%
# column : 위도 Nan value percentage : 0.0%

# %%
plt.figure(figsize=(10, 8))  # 그래프의 크기를 조절합니다.

g = sns.barplot(
    y=Top_Lib.nunique()[2:].index,
    x=Top_Lib.nunique()[2:].values
)

# 숫자 표시
for p in g.patches:
    g.text(
        p.get_x() + p.get_width(),
        p.get_y() + (p.get_height() / 2),
        f"{p.get_width():.0f}",
        ha='center',
        fontsize=7  # 폰트 크기를 조절합니다.
    )

g.set_title('분석할 데이터의 항목 분석')

# y 축의 눈금 레이블 크기 조정
g.tick_params(axis='y', labelsize=7)

plt.show()

# %%
### 2. 데이터 수치 살펴보기
Top_Lib.describe().style.background_gradient(cmap='pink_r')
# Out:
# <style type="text/css">
# #T_92d95_row0_col0, #T_92d95_row0_col1, #T_92d95_row0_col5, #T_92d95_row0_col6, #T_92d95_row0_col7, #T_92d95_row0_col9, #T_92d95_row0_col10, #T_92d95_row0_col12, #T_92d95_row0_col15, #T_92d95_row0_col16, #T_92d95_row7_col2, #T_92d95_row7_col3, #T_92d95_row7_col4, #T_92d95_row7_col8, #T_92d95_row7_col11 {
#   background-color: #1e0000;
#   color: #f1f1f1;
# }
# #T_92d95_row0_col2, #T_92d95_row0_col3, #T_92d95_row0_col4, #T_92d95_row0_col8, #T_92d95_row0_col13, #T_92d95_row0_col14, #T_92d95_row1_col0, #T_92d95_row1_col5, #T_92d95_row1_col7, #T_92d95_row1_col9, #T_92d95_row1_col10, #T_92d95_row1_col13, #T_92d95_row1_col14, #T_92d95_row1_col15, #T_92d95_row1_col16, #T_92d95_row2_col0, #T_92d95_row2_col1, #T_92d95_row2_col2, #T_92d95_row2_col5, #T_92d95_row2_col7, #T_92d95_row2_col10, #T_92d95_row2_col11, #T_92d95_row2_col12, #T_92d95_row2_col13, #T_92d95_row2_col14, #T_92d95_row2_col15, #T_92d95_row2_col16, #T_92d95_row3_col0, #T_92d95_row3_col4, #T_92d95_row3_col5, #T_92d95_row3_col6, #T_92d95_row3_col7, #T_92d95_row3_col9, #T_92d95_row3_col10, #T_92d95_row3_col13, #T_92d95_row3_col14, #T_92d95_row3_col15, #T_92d95_row3_col16, #T_92d95_row4_col0, #T_92d95_row4_col5, #T_92d95_row4_col6, #T_92d95_row4_col7, #T_92d95_row4_col9, #T_92d95_row4_col10, #T_92d95_row4_col13, #T_92d95_row4_col14, #T_92d95_row4_col15, #T_92d95_row4_col16, #T_92d95_row5_col0, #T_92d95_row5_col5, #T_92d95_row5_col6, #T_92d95_row5_col7, #T_92d95_row5_col9, #T_92d95_row5_col10, #T_92d95_row5_col13, #T_92d95_row5_col14, #T_92d95_row5_col15, #T_92d95_row5_col16, #T_92d95_row6_col0, #T_92d95_row6_col5, #T_92d95_row6_col7, #T_92d95_row6_col9, #T_92d95_row6_col10, #T_92d95_row6_col13, #T_92d95_row6_col14, #T_92d95_row6_col15, #T_92d95_row6_col16, #T_92d95_row7_col0, #T_92d95_row7_col5, #T_92d95_row7_col13, #T_92d95_row7_col14, #T_92d95_row7_col15, #T_92d95_row7_col16 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_92d95_row0_col11, #T_92d95_row6_col12 {
#   background-color: #e5e1b0;
#   color: #000000;
# }
# #T_92d95_row1_col1, #T_92d95_row5_col1, #T_92d95_row6_col1 {
#   background-color: #dbc7a2;
#   color: #000000;
# }
# #T_92d95_row1_col2, #T_92d95_row1_col3, #T_92d95_row1_col4, #T_92d95_row1_col8 {
#   background-color: #280d0d;
#   color: #f1f1f1;
# }
# #T_92d95_row1_col6, #T_92d95_row2_col3, #T_92d95_row2_col6, #T_92d95_row2_col8, #T_92d95_row2_col9, #T_92d95_row6_col6 {
#   background-color: #fffffe;
#   color: #000000;
# }
# #T_92d95_row1_col11 {
#   background-color: #523232;
#   color: #f1f1f1;
# }
# #T_92d95_row1_col12 {
#   background-color: #e6e2b0;
#   color: #000000;
# }
# #T_92d95_row2_col4 {
#   background-color: #fefefd;
#   color: #000000;
# }
# #T_92d95_row3_col1, #T_92d95_row4_col1 {
#   background-color: #dbc8a2;
#   color: #000000;
# }
# #T_92d95_row3_col2, #T_92d95_row3_col3, #T_92d95_row3_col8, #T_92d95_row4_col2, #T_92d95_row4_col3, #T_92d95_row4_col4, #T_92d95_row4_col8, #T_92d95_row5_col2, #T_92d95_row5_col3, #T_92d95_row5_col4, #T_92d95_row5_col8, #T_92d95_row6_col2, #T_92d95_row6_col3, #T_92d95_row6_col4, #T_92d95_row6_col8 {
#   background-color: #2d1313;
#   color: #f1f1f1;
# }
# #T_92d95_row3_col11 {
#   background-color: #764b4b;
#   color: #f1f1f1;
# }
# #T_92d95_row3_col12 {
#   background-color: #e7e5b2;
#   color: #000000;
# }
# #T_92d95_row4_col11 {
#   background-color: #5e3a3a;
#   color: #f1f1f1;
# }
# #T_92d95_row4_col12 {
#   background-color: #e6e4b1;
#   color: #000000;
# }
# #T_92d95_row5_col11 {
#   background-color: #5b3939;
#   color: #f1f1f1;
# }
# #T_92d95_row5_col12 {
#   background-color: #e6e3b1;
#   color: #000000;
# }
# #T_92d95_row6_col11 {
#   background-color: #452929;
#   color: #f1f1f1;
# }
# #T_92d95_row7_col1 {
#   background-color: #dac6a1;
#   color: #000000;
# }
# #T_92d95_row7_col6 {
#   background-color: #fcfcf7;
#   color: #000000;
# }
# #T_92d95_row7_col7 {
#   background-color: #fdfdfa;
#   color: #000000;
# }
# #T_92d95_row7_col9 {
#   background-color: #f9f9ee;
#   color: #000000;
# }
# #T_92d95_row7_col10 {
#   background-color: #fefefc;
#   color: #000000;
# }
# #T_92d95_row7_col12 {
#   background-color: #e4dfae;
#   color: #000000;
# }
# </style>
# <table id="T_92d95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92d95_level0_col0" class="col_heading level0 col0" >시도코드</th>
#       <th id="T_92d95_level0_col1" class="col_heading level0 col1" >시군구코드</th>
#       <th id="T_92d95_level0_col2" class="col_heading level0 col2" >행정동코드</th>
#       <th id="T_92d95_level0_col3" class="col_heading level0 col3" >법정동코드</th>
#       <th id="T_92d95_level0_col4" class="col_heading level0 col4" >지번코드</th>
#       <th id="T_92d95_level0_col5" class="col_heading level0 col5" >대지구분코드</th>
#       <th id="T_92d95_level0_col6" class="col_heading level0 col6" >지번본번지</th>
#       <th id="T_92d95_level0_col7" class="col_heading level0 col7" >지번부번지</th>
#       <th id="T_92d95_level0_col8" class="col_heading level0 col8" >도로명코드</th>
#       <th id="T_92d95_level0_col9" class="col_heading level0 col9" >건물본번지</th>
#       <th id="T_92d95_level0_col10" class="col_heading level0 col10" >건물부번지</th>
#       <th id="T_92d95_level0_col11" class="col_heading level0 col11" >구우편번호</th>
#       <th id="T_92d95_level0_col12" class="col_heading level0 col12" >신우편번호</th>
#       <th id="T_92d95_level0_col13" class="col_heading level0 col13" >동정보</th>
#       <th id="T_92d95_level0_col14" class="col_heading level0 col14" >호정보</th>
#       <th id="T_92d95_level0_col15" class="col_heading level0 col15" >경도</th>
#       <th id="T_92d95_level0_col16" class="col_heading level0 col16" >위도</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92d95_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_92d95_row0_col0" class="data row0 col0" >111528.000000</td>
#       <td id="T_92d95_row0_col1" class="data row0 col1" >111528.000000</td>
#       <td id="T_92d95_row0_col2" class="data row0 col2" >111528.000000</td>
#       <td id="T_92d95_row0_col3" class="data row0 col3" >111528.000000</td>
#       <td id="T_92d95_row0_col4" class="data row0 col4" >111528.000000</td>
#       <td id="T_92d95_row0_col5" class="data row0 col5" >111528.000000</td>
#       <td id="T_92d95_row0_col6" class="data row0 col6" >111519.000000</td>
#       <td id="T_92d95_row0_col7" class="data row0 col7" >74734.000000</td>
#       <td id="T_92d95_row0_col8" class="data row0 col8" >111528.000000</td>
#       <td id="T_92d95_row0_col9" class="data row0 col9" >111528.000000</td>
#       <td id="T_92d95_row0_col10" class="data row0 col10" >29646.000000</td>
#       <td id="T_92d95_row0_col11" class="data row0 col11" >111528.000000</td>
#       <td id="T_92d95_row0_col12" class="data row0 col12" >111528.000000</td>
#       <td id="T_92d95_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_92d95_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_92d95_row0_col15" class="data row0 col15" >111528.000000</td>
#       <td id="T_92d95_row0_col16" class="data row0 col16" >111528.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92d95_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_92d95_row1_col0" class="data row1 col0" >44.000000</td>
#       <td id="T_92d95_row1_col1" class="data row1 col1" >44318.111972</td>
#       <td id="T_92d95_row1_col2" class="data row1 col2" >44318537.654168</td>
#       <td id="T_92d95_row1_col3" class="data row1 col3" >4431831664.023644</td>
#       <td id="T_92d95_row1_col4" class="data row1 col4" >4431474890288554496.000000</td>
#       <td id="T_92d95_row1_col5" class="data row1 col5" >1.002771</td>
#       <td id="T_92d95_row1_col6" class="data row1 col6" >573.747397</td>
#       <td id="T_92d95_row1_col7" class="data row1 col7" >16.222054</td>
#       <td id="T_92d95_row1_col8" class="data row1 col8" >443184897314.721191</td>
#       <td id="T_92d95_row1_col9" class="data row1 col9" >213.732856</td>
#       <td id="T_92d95_row1_col10" class="data row1 col10" >13.509276</td>
#       <td id="T_92d95_row1_col11" class="data row1 col11" >336681.289990</td>
#       <td id="T_92d95_row1_col12" class="data row1 col12" >31984.753174</td>
#       <td id="T_92d95_row1_col13" class="data row1 col13"

# %%
# 천안시 서북구 동남구만 추출
Cheonan_Seo_dong = Top_Lib[Top_Lib['시군구명'].str.contains('천안시')]


# 충청남도 천안시 서북구 동남구의 카페, 토스트/샌드위치/샐러드, 빵/도넛, 생수/음료 소매업 추출
Cheonan_Seo_Dong_Cafe = Cheonan_Seo_dong[(Cheonan_Seo_dong['상권업종소분류명'] == '카페')]

# %%
Si_gun_gu = Cheonan_Seo_Dong_Cafe.groupby(['상권업종소분류명', '행정동명']).size()

df = pd.DataFrame(list(Si_gun_gu.items()), columns=['Ranking', 'Value'])
df[['상권업종소분류명', '행정동명']] = pd.DataFrame(df['Ranking'].tolist(), index=df.index)

df['상권업종소분류명'] = pd.Categorical(df['상권업종소분류명'])

df['행정동명'] = pd.Categorical(df['행정동명'], ordered=True)

df.sort_values(by='상권업종소분류명', inplace=True)

plt.figure(figsize=(20, 10))
ax = sns.barplot(x='상권업종소분류명', y='Value', hue='행정동명', data=df, palette='viridis')

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
# 충청남도 천안시 서북구만 따로 추출하여 변수 생성    ※ 충남 계룡, 보령 등 다른 지역은 상관없어서 제거
Cheonan_Seobuk = Top_Lib[Top_Lib['시군구명'] == '천안시 서북구']

# 충청남도 천안시의 데이터만 따로 추출하여 변수 생성    ※ 충남 계룡, 보령 등 다른 지역은 상관없어서 제거
Cheonan_All = Top_Lib[Top_Lib['시군구명'].str.contains('천안시')]

# %%
Cheonan_Seobuk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19055 entries, 3 to 111520
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     19055 non-null  object
#  1   상호명        19055 non-null  object
#  2   지점명        423 non-null    object
#  3   상권업종대분류코드  19055 non-null  object
#  4   상권업종대분류명   19055 non-null  object
#  5   상권업종중분류코드  19055 non-null  object
#  6   상권업종중분류명   19055 non-null  object
#  7   상권업종소분류코드  19055 non-null  object
#  8   상권업종소분류명   19055 non-null  object
#  9   표준산업분류코드   19053 non-null  object
#  10  표준산업분류명    19053 non-null  object
#  11  시도코드       19055 non-null  int64
#  12  시도명        19055 non-null  object
#  13  시군구코드      19055 non-null  int64
#  14  시군구명       19055 non-null  object
#  15  행정동코드      19055 non-null  int64
#  16  행정동명       19055 non-null  object
#  17  법정동코드      19055 non-null  int64
#  18  법정동명       19055 non-null  object
#  19  지번코드       19055 non-null  int64
#  20  대지구분코드     19055 non-null  int64
#  21  대지구분명      19055 non-null  object
#  22  지번본번지      19055 non-null  float64
#  23  지번부번지      7236 non-null   float64
#  24  지번주소       19055 non-null  object
#  25  도로명코드      19055 non-null  int64
#  26  도로명        19055 non-null  object
#  27  건물본번지      19055 non-null  int64
#  28  건물부번지      3622 non-null   float64
#  29  건물관리번호     19055 non-null  object
#  30  건물명        10595 non-null  object
#  31  도로명주소      19055 non-null  object
#  32  구우편번호      19055 non-null  int64
#  33  신우편번호      19055 non-null  int64
#  34  동정보        0 non-null      float64
#  35  층정보        10120 non-null  object
#  36  호정보        0 non-null      float64
#  37  경도         19055 non-null  float64
#  38  위도         19055 non-null  float64
# dtypes: float64(7), int64(10), object(22)
# memory usage: 5.8+ MB

# %%
# 충청남도 천안시 서북구 
Cheonan_Seobu0k_Cafe = Cheonan_Seobuk[(Cheonan_Seobuk['상권업종소분류명'] == '카페') | 
                                      (Cheonan_Seobuk['상권업종소분류명'] == '토스트/샌드위치/샐러드') | 
                                      (Cheonan_Seobuk['상권업종소분류명'] == '빵/도넛') | 
                                      (Cheonan_Seobuk['상권업종소분류명'] == '생수/음료 소매업')]


# 충청남도 천안시 서북구 동남구 전체 
Cheonan_All_Cafe = Cheonan_All[(Cheonan_All['상권업종소분류명'] == '카페') | 
                                      (Cheonan_All['상권업종소분류명'] == '토스트/샌드위치/샐러드') | 
                                      (Cheonan_All['상권업종소분류명'] == '빵/도넛') | 
                                      (Cheonan_All['상권업종소분류명'] == '생수/음료 소매업')]

# %%
import matplotlib.pyplot as plt

# 분석할 업종들
target_categories = ['카페', '토스트/샌드위치/샐러드', '빵/도넛', '생수/음료 소매업']

# 특정 업종에 해당하는 데이터만 필터링
filtered_data = Cheonan_Seobu0k_Cafe[Cheonan_Seobu0k_Cafe['상권업종소분류명'].isin(target_categories)]

# 행정동별로 업종 비율 계산
grouped = filtered_data.groupby('행정동명')['상권업종소분류명'].value_counts(normalize=True).unstack().fillna(0)

# 행정동별 업종 비율을 막대 그래프로 시각화
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(20, 30))  # 그림의 크기를 크게 조정합니다.
plt.rcParams.update({'font.size': 11})

for i, (index, row) in enumerate(grouped.iterrows()):
    ax = axes[i // 5, i % 5]  # 그리드에 대한 인덱스를 계산합니다.
    row.plot(kind='bar', ax=ax)
    ax.set_title(index + '의 업종 비율')
    ax.set_ylabel('비율')
    ax.set_xlabel('업종')
    ax.set_xticklabels(row.index, rotation=45, ha='right')  # X 축 라벨 회전
plt.tight_layout()
plt.show()

# %%
import folium
from folium.plugins import MarkerCluster

map = folium.Map(location=[36.8065, 127.1526], zoom_start = 13)
marker_cluster = MarkerCluster().add_to(map)

# 각 카페 위치에 마커를 추가 
# 천안시 서북구만 출력 = Cheonan_Seobu0k_Cafe
# 천안시 서북구 동남구 모두 출력 = Cheonan_All_Cafe
for index, row in Cheonan_Seobu0k_Cafe.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],  # 위치 설정
        icon=None  # 아이콘 없이 표시
    ).add_to(marker_cluster)

# 지도 출력
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56ab38905aa65cc21c42d59fe37ab699 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56ab38905aa65cc21c42d59fe37ab699&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56ab38905aa65cc21c42d59fe37ab699 = L.map(
#                 &quot;map_56ab38905aa65cc21c42d59fe37ab699&quot;,
#                 {
#                     center: [36.8065, 127.1526],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70db639c4cc21ae6f483c3f68c3b99d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70db639c4cc21ae6f483c3f68c3b99d7.addTo(map_56ab38905aa65cc21c42d59fe37ab699);
#
#
#             var marker_cluster_3721ec1bfbbf58800812353957d925db = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f403b115fdbff1195540a57a0e364e12 = L.marker(
#                 [36.8330893652718, 127.147572832313],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_b1d5e0444e896ba1b85a10273050324c = L.marker(
#                 [36.822107810522, 127.126957812003],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_426b36265027dbcfd5d4acf08c6aa6da = L.marker(
#                 [36.8339917621432, 127.135264531999],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_4730b8be72fb863a486e0d1abb21b897 = L.marker(
#                 [36.8262431434851, 127.126821155091],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_b4868f13f855476f9a96278ee304b51e = L.marker(
#                 [36.840397663019, 127.101063842343],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_813c961a75f024c39ecaed88aca19cab = L.marker(
#                 [36.7978151725596, 127.117563208796],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_8e7c1fae81b694711a0098ff75ce4d7b = L.marker(
#                 [36.8332474614609, 127.146999330785],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_a57542accbdc29d9e59839aa2f0ac08f = L.marker(
#                 [36.9161136186526, 127.127806586128],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_91f14d3bfee401d12611b5d8b22746ef = L.marker(
#                 [36.8353378903825, 127.144453636288],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_75db16e924aaa5ba7cc37397f98bc2d4 = L.marker(
#                 [36.8304624574521, 127.136952171321],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_e7c6d6f27ac34cb26490b3f746691818 = L.marker(
#                 [36.8323983373402, 127.147972870799],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_2f71dddbbd9b68431f9b45e5b6d9b50d = L.marker(
#                 [36.8267780213216, 127.117488550775],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_af34f798e8969334ac81cfcb41e3826f = L.marker(
#                 [36.8018357346824, 127.118962673137],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_a87b3cf3ad672877f56d346f86286272 = L.marker(
#                 [36.9161136186526, 127.127806586128],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_3df7088d2eba4d898d7239737c27a945 = L.marker(
#                 [36.815077653808, 127.141664188636],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d925db);
#
#
#             var marker_b5b18f6af08843f1c14fb32cd04fd9b9 = L.marker(
#                 [36.8041022510596, 127.10869401048],
#                 {}
#             ).addTo(marker_cluster_3721ec1bfbbf58800812353957d9

# %% [markdown]
# #### 2 # 카페 프랜차이즈별 창업비용 및 고정지출에 대한 분석

# %%
기술통계량 확인: 각 열의 기술통계량을 계산하여 데이터의 분포를 파악합니다. 평균, 중앙값, 표준편차 등을 확인하여 데이터의 대략적인 특성을 이해할 수 있습니다.

히스토그램 그리기: 각 열에 대한 히스토그램을 그려서 데이터의 분포를 시각화할 수 있습니다. 이를 통해 데이터의 분산과 이상치를 파악할 수 있습니다.

상관관계 분석: 각 열 간의 상관관계를 분석하여 변수들 간의 관련성을 파악할 수 있습니다. 이를 통해 예상치 못한 관계나 데이터의 패턴을 발견할 수 있습니다.

박스 플롯 그리기: 각 열의 박스 플롯을 그려서 이상치를 시각화하고 분포의 대표값을 확인할 수 있습니다.

카테고리별 분석: 가맹점명 등 카테고리 변수에 따라 데이터를 그룹화하고 각 그룹별로 특성을 비교해 볼 수 있습니다.

지도 시각화: 매장의 위치 정보가 있다면 지도에 매장을 표시하여 지리적 분포를 시각화할 수 있습니다.

클러스터링 분석: 데이터의 특성에 따라 클러스터링을 수행하여 비슷한 특성을 갖는 데이터끼리 그룹화할 수 있습니다.

가격 대비 성능 분석: 최소 예상 창업 비용과 월 매출 평균을 비교하여 가격 대비 성능을 분석할 수 있습니다.
